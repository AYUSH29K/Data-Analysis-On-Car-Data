# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns # imported seaborn for box-plot

# %%
import matplotlib.pyplot as plt # imported matplotlib.pyplot for scatter-plot

# %%
url = "https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DA0101EN/auto.csv"

# %%
df=pd.read_csv(url)

# %%
headers = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]

# %%
df.columns = headers

# %%
df.head() # Now the DataSet is ready!
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          1                 ?  alfa-romero       gas        std          two
# 2          2               164         audi       gas        std         four
# 3          2               164         audi       gas        std         four
# 4          2                 ?         audi       gas        std          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1    hatchback          rwd           front        94.5  ...          152
# 2        sedan          fwd           front        99.8  ...          109
# 3        sedan          4wd           front        99.4  ...          136
# 4        sedan          fwd           front        99.8  ...          136
#
# ...

# %%
# Descriptive Statistics 
df.describe() # returns a statistical summary (short)
# Out:
#         symboling  wheel-base      length       width      height  \
# count  204.000000  204.000000  204.000000  204.000000  204.000000
# mean     0.823529   98.806373  174.075000   65.916667   53.749020
# std      1.239035    5.994144   12.362123    2.146716    2.424901
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.075000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.200000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   204.000000   204.000000         204.000000  204.000000   204.000000
# mean   2555.602941   126.892157          10.148137   25.240196    30.769608
# std     521.960820    41.744569           3.981000    6.551513     6.898337
# ...

# %%
drive_wheels_counts=df["drive-wheels"].value_counts() # using the function value_counts() for descriptive statistics
# a var is defined and the value_counts of the column is assigned to it  (summarizing categorical data)

# %%
drive_wheels_counts=df.rename(columns={'drive-wheels':'value_counts'},inplace = True) # columns renamed

# %%
drive_wheels_counts=df.index.name='drive-wheels' #index created and named

# %%
df["value_counts"].value_counts()
# to display the result, shows 2 more as index added and a space before categorization
# Out:
# fwd    120
# rwd     75
# 4wd      9
# Name: value_counts, dtype: int64

# %%
df.price = pd.to_numeric(df.price, errors='coerce').fillna(0).astype(np.int64)

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# value_counts          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                  int64
# dtype: object

# %%
sns.boxplot(x="engine-size",y="price",data=df) #using box-plot for comparison b/w percentiles and data b/w 2 columns
# here b/w price and engine-size, a box-plot is plotted
# Out:
# <AxesSubplot:xlabel='engine-size', ylabel='price'>

# %%
z= df["price"] # defining the target var on the y axis

# %%
w= df["engine-size"] # defining the predictor var on the x axis

# %%
plt.title("Price v/s Engine-Size") # plot title
plt.xlabel("Engine-Size") # x and y labels
plt.ylabel("Price")
plt.scatter(w,z) # plotting the scatter-plot

# %%
df.head()
# Out:
#               symboling normalized-losses         make fuel-type aspiration  \
# drive-wheels
# 0                     3                 ?  alfa-romero       gas        std
# 1                     1                 ?  alfa-romero       gas        std
# 2                     2               164         audi       gas        std
# 3                     2               164         audi       gas        std
# 4                     2                 ?         audi       gas        std
#
#              num-of-doors   body-style value_counts engine-location  \
# drive-wheels
# 0                     two  convertible          rwd           front
# 1                     two    hatchback          rwd           front
# 2                    four        sedan          fwd           front
# 3                    four        sedan          4wd           front
# 4                     two        sedan          fwd           front
#
# ...

# %%
#Group By
df_test=df[['horsepower','peakrpm','price']] # Choose the columns b/w which you want a comparison

# %%
df_grp=df_test.groupby(['horsepower','peakrpm'],as_index=False).mean() 
# Choosing to take the mean of each group and then append it to line 2
df_grp # Display the group by created (subcat created and grouped a/c to avg price)
# Out:
#     horsepower  peakrpm    price
# 0            0        0   9595.0
# 1           48     5100   5151.0
# 2           52     4800   7885.0
# 3           55     4800   7099.0
# 4           56     4500   7843.0
# ..         ...      ...      ...
# 71         184     4500  43180.0
# 72         200     5200  19699.0
# 73         207     5900  34528.0
# 74         262     5000  36000.0
# 75         288     5750      0.0
#
# [76 rows x 3 columns]

# %%
df_pivot=df_grp.pivot(index='horsepower',columns='peakrpm') # adding a pivot the the group just made

# %%
df_pivot # display the pivot created
# Out:
#              price                                                            \
# peakrpm       0        4150     4200          4250     4350    4400     4500
# horsepower
# 0           9595.0      NaN      NaN           NaN      NaN     NaN      NaN
# 48             NaN      NaN      NaN           NaN      NaN     NaN      NaN
# 52             NaN      NaN      NaN           NaN      NaN     NaN      NaN
# 55             NaN      NaN      NaN           NaN      NaN     NaN      NaN
# 56             NaN      NaN      NaN           NaN      NaN     NaN   7843.0
# 58             NaN      NaN      NaN           NaN      NaN     NaN      NaN
# 60             NaN      NaN      NaN           NaN      NaN     NaN      NaN
# 62             NaN      NaN      NaN           NaN      NaN     NaN      NaN
# 64             NaN      NaN      NaN           NaN      NaN     NaN      NaN
# 68             NaN      NaN      NaN           NaN      NaN     NaN  11670.0
# ...

# %%
plt.pcolor(df_pivot,cmap='RdBu') # Adding a heat map to the pivot just made and assigning color map as RedBlu
plt.colorbar() #Display colobar
plt.show() #Display the Heat-Map

# %%
# ANOVA
df_anova=df[["make","price"]] # select the columns on which ANOVA has to be performed

# %%
grouped_anova=df_anova.groupby(["make"]) # group by 'make' column

# %%
import scipy.stats as stats # import scipy.stats as it contains one way anova functionality

# %%
anova_results_1=stats.f_oneway(grouped_anova.get_group("honda")["price"],grouped_anova.get_group("subaru")["price"])
# use stats.f_oneway to find the f and p-value b/w groups (here-2 groups) to determine weak/strong correlation 
# honda and subaru groups compared

# %%
print(anova_results_1)  # weak correlation as f value < 1 and p value > 0.05 also
# Out:
# F_onewayResult(statistic=0.19744030127462606, pvalue=0.6609478240622193)

# %%
anova_results_2=stats.f_oneway(grouped_anova.get_group("honda")["price"],grouped_anova.get_group("jaguar")["price"])

# %%
print(anova_results_2) # strong correlation as f value > 1 and p value < 0.05
# Out:
# F_onewayResult(statistic=400.925870564337, pvalue=1.0586193512077862e-11)

# %%
df["engine-size"]=df["engine-size"].astype("float")

# %%
df["highway-mpg"]=df["highway-mpg"].astype("float")

# %%
# Correlation
sns.regplot(x="engine-size",y="price",data=df) # postive linear relationship
plt.ylim(0, )
# Out:
# (0.0, 52690.38326348352)

# %%
sns.regplot(x="highway-mpg",y="price",data=df) # negative linear relationship
plt.ylim(0, )
# Out:
# (0.0, 48144.80684323161)

# %%
df.rename(columns={"peak-rpm":"peakrpm"},inplace=True)

# %%
df.peakrpm = pd.to_numeric(df.peakrpm, errors='coerce').fillna(0).astype(np.int64)

# %%
sns.regplot(x="peakrpm",y="price",data=df) # weak correlation (as slope is flat, all other cases slope steep : good indicator)
plt.ylim(0, )
# Out:
# (0.0, 47670.0)

# %%
# pearson correlation
from scipy.stats import pearsonr # to use pearsonr import it from scipy.stats

# %%
df.price = pd.to_numeric(df.price, errors='coerce').fillna(0).astype(np.int64)

# %%
df.horsepower = pd.to_numeric(df.horsepower, errors='coerce').fillna(0).astype(np.int64)

# %%
pearson_coef,p_value = stats.pearsonr(df['horsepower'],df['price'])
# calculating pearson coefficient  and p-value b/w 2 groups i.e. horespower and price 
# determining the strength of correlation by these values

# %%
print(pearson_coef,p_value)
# Out:
# 0.6912939296171078 2.517436153885049e-30

# %%
#Below are additional statements a/c to jupyter lab module 3
df[['bore', 'stroke', 'compression-ratio', 'horsepower']].corr() #Simple correlation b/w 4 columns' data
# Out:
#                    compression-ratio
# compression-ratio                1.0

# %%
df.describe(include=['object']) #includes the variable type - object as the default one skips that i.e. df.describe()
# Out:
#        normalized-losses    make fuel-type aspiration num-of-doors body-style  \
# count                205     205       205        205          205        205
# unique                52      22         2          2            3          5
# top                    ?  toyota       gas        std         four      sedan
# freq                  41      32       185        168          114         96
#
#        value_counts engine-location engine-type num-of-cylinders fuel-system  \
# count           205             205         205              205         205
# unique            3               2           7                7           8
# top             fwd           front         ohc             four        mpfi
# freq            120             202         148              159          94
#
#         bore stroke horsepower peak-rpm price
# count    205    205        205      205   205
# unique    39     37         60       24   187
# top     3.62   3.40         68     5500     ?
# ...
